# %%
import pandas as pd
import numpy as np
import folium
import requests

# %%
from data_functions import convert_to_numpy, add_points_to_map, get_elevation, get_elevation_for_array

# %%
# Read the CSV files into pandas DataFrames
file0 = '../../data/20230608/Points_Coastal_0p01degSpacing_For_Extraction_of_TS_FLS_EastCoast.csv'
file25 = '../../data/20230608/Points_DepthContour25m_0p01degSpacing_For_Extraction_of_TS_FLS_EastCoast.csv'
file50 = '../../data/20230608/Points_DepthContour50m_0p01degSpacing_For_Extraction_of_TS_FLS_EastCoast.csv'

df0 = pd.read_csv(file0)
df25 = pd.read_csv(file25)
df50 = pd.read_csv(file50)

# Ensure that the columns are named "X", "Y", and "ID" in each CSV
# Convert the DataFrames to the desired numpy array structure

array0 = convert_to_numpy(df0)
array25 = convert_to_numpy(df25)
array50 = convert_to_numpy(df50)

print(array0)
print(array25)
print(array50)

np.save('../data/20230608/Loc0m.npy',array0)
np.save('../data/20230608/Loc25m.npy',array25)
np.save('../data/20230608/Loc50m.npy',array50)
# Out:
# [[  1.         -80.15736793  27.16312726]
#  [  2.         -80.1544187   27.15425913]
#  [  3.         -80.15046804  27.14512698]
#  [  4.         -80.14727994  27.1356871 ]
#  [  5.         -80.1439641   27.12627286]
#  [  6.         -80.14114564  27.11669397]
#  [  7.         -80.13705241  27.10759669]
#  [  8.         -80.13220763  27.0988674 ]
#  [  9.         -80.12717951  27.09023494]
#  [ 10.         -80.12193175  27.08181124]
#  [ 11.         -80.11742418  27.0728954 ]
#  [ 12.         -80.11353682  27.06373033]
#  [ 13.         -80.1089165   27.05487456]
#  [ 14.         -80.10505684  27.0456503 ]
#  [ 15.         -80.10122687  27.0364709 ]
#  [ 16.         -80.09744742  27.02722751]
#  [ 17.         -80.0939785   27.01786091]
#  [ 18.         -80.09103264  27.0083168 ]
#  [ 19.         -80.08870413  26.99862951]
#  [ 20.         -80.08645132  26.98891476]
#  [ 21.         -80.08305411  26.97952013]
#  [ 22.         -80.08027869  26.97001046]
# ...

# %%
# Create a base map, you can adjust the initial coordinates and zoom as needed
m = folium.Map(location=[27, -80], zoom_start=10)

# Adding points from array1 in blue, from array2 in red, and from array3 in green
add_points_to_map(array0, m, "blue")
add_points_to_map(array25, m, "red")
add_points_to_map(array50, m, "green")

# Save the map to an HTML file for viewing in a browser
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# # Test distance function
# loc1 = array0[0]  # Berlin, Germany
# loc2 = array25[0]   # Paris, France
# print(haversine_distance(loc1, loc2), "km")
# Out:
# 28.24448144474362 km

# %%
# AIzaSyCZkTSEvEECdtVMhKFdHkknVPttidNmaNg

# %%
# Test
api_key = "AIzaSyCZkTSEvEECdtVMhKFdHkknVPttidNmaNg"
array0_with_elevation = get_elevation_for_array(array0, api_key)
print(array0_with_elevation)
# Out:
# [[ 1.00000000e+00 -8.01573679e+01  2.71631273e+01  3.28047485e+03]
#  [ 2.00000000e+00 -8.01544187e+01  2.71542591e+01  3.28041382e+03]
#  [ 3.00000000e+00 -8.01504680e+01  2.71451270e+01  3.28034741e+03]
#  [ 4.00000000e+00 -8.01472799e+01  2.71356871e+01  3.28012524e+03]
#  [ 5.00000000e+00 -8.01439641e+01  2.71262729e+01  3.28010840e+03]
#  [ 6.00000000e+00 -8.01411456e+01  2.71166940e+01  3.28003687e+03]
#  [ 7.00000000e+00 -8.01370524e+01  2.71075967e+01  3.27999756e+03]
#  [ 8.00000000e+00 -8.01322076e+01  2.70988674e+01  3.28000000e+03]
#  [ 9.00000000e+00 -8.01271795e+01  2.70902349e+01  3.27997241e+03]
#  [ 1.00000000e+01 -8.01219318e+01  2.70818112e+01  3.28006372e+03]
#  [ 1.10000000e+01 -8.01174242e+01  2.70728954e+01  3.28016553e+03]
#  [ 1.20000000e+01 -8.01135368e+01  2.70637303e+01  3.28041406e+03]
#  [ 1.30000000e+01 -8.01089165e+01  2.70548746e+01  3.28100757e+03]
#  [ 1.40000000e+01 -8.01050568e+01  2.70456503e+01  3.28131055e+03]
# ...

# %%
np.save('../../data/20230608/Loc0mEle.npy',array0_with_elevation)
